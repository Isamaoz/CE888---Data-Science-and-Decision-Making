# %% [markdown]
# <a href="https://colab.research.google.com/github/Isamaoz/CE888---Data-Science-and-Decision-Making/blob/master/Lab4_bank_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/albanda/CE888/master/lab4/bank-additional-full.csv", delimiter = ";")
df.head()
# Out:
#    age        job  marital  ... euribor3m nr.employed   y
# 0   56  housemaid  married  ...     4.857      5191.0  no
# 1   57   services  married  ...     4.857      5191.0  no
# 2   37   services  married  ...     4.857      5191.0  no
# 3   40     admin.  married  ...     4.857      5191.0  no
# 4   56   services  married  ...     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
df_dummies = pd.get_dummies(df)
df_dummies.head()
# Out:
#    age  duration  campaign  ...  poutcome_success  y_no  y_yes
# 0   56       261         1  ...                 0     1      0
# 1   57       149         1  ...                 0     1      0
# 2   37       226         1  ...                 0     1      0
# 3   40       151         1  ...                 0     1      0
# 4   56       307         1  ...                 0     1      0
#
# [5 rows x 65 columns]

# %%
df_copy = df_dummies
df_copy.pop("y_no")
df_copy.pop("duration")
df_copy.head()
# Out:
#    age  campaign  pdays  ...  poutcome_nonexistent  poutcome_success  y_yes
# 0   56         1    999  ...                     1                 0      0
# 1   57         1    999  ...                     1                 0      0
# 2   37         1    999  ...                     1                 0      0
# 3   40         1    999  ...                     1                 0      0
# 4   56         1    999  ...                     1                 0      0
#
# [5 rows x 63 columns]

# %%
import seaborn as sns
import matplotlib
import numpy as np
import matplotlib.pyplot asx

sns_plot = sns.distplot(df_copy["y_yes"], kde=False, rug=True)

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import make_scorer, confusion_matrix
from sklearn.dummy import DummyRegressor, DummyClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
features = df_copy.drop("y_yes",axis=1)
outcome = df_copy["y_yes"]

X_df = features.copy()
Y_df = outcome.copy()

x_train, x_test, y_train, y_test = train_test_split(X_df,Y_df,test_size=0.3,random_state=1)
clf = ExtraTreesClassifier(n_estimators=1000, max_depth=4)

# %%
clf = clf.fit(x_train, y_train)
y_prediction = clf.predict(x_test)

# %%
#Cross-validation
scores = cross_val_score(clf, x_train, y_train, cv= 10, scoring = make_scorer(acc))
dummy_clf = DummyClassifier()
dummy_clf.fit(x_train, y_train)
print("ACC: %0.2f +/- %0.2f" % (scores.mean(), scores.std()))
print("Dummy ACC: %0.2f"% (acc(y_test,dummy_clf.predict(x_test))))
# Out:
# ACC: 0.90 +/- 0.00
# Dummy ACC: 0.80
# /usr/local/lib/python3.6/dist-packages/sklearn/dummy.py:132: FutureWarning: The default value of strategy will change from stratified to prior in 0.24.
#   "stratified to prior in 0.24.", FutureWarning)

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

#Sample importances

importances = clf.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

print("Feature ranking:")
features=list(df_copy.columns)
for f in range(X_df.shape[1]):
    print("%d. %s (%f)" % (f + 1, features[indices[f]],  importances[indices[f]]))

fig = plt.figure()
plt.title("Bank Classification")
plt.bar(range(X_df.shape[1]), importances[indices],
       color="b", yerr=std[indices], align="center")
plt.xticks(range(X_df.shape[1]), np.array(features)[indices],rotation=90)
plt.xlim([-1, X_df.shape[1]])
fig.set_size_inches(15,8)
axes = plt.gca()
axes.set_ylim([0,None])
# Out:
# Feature ranking:
# 1. pdays (0.170724)
# 2. poutcome_success (0.168883)
# 3. nr.employed (0.139971)
# 4. euribor3m (0.116848)
# 5. emp.var.rate (0.088788)
# 6. poutcome_nonexistent (0.038066)
# 7. month_mar (0.031159)
# 8. cons.conf.idx (0.029786)
# 9. cons.price.idx (0.026756)
# 10. month_may (0.025649)
# 11. contact_cellular (0.018389)
# 12. month_oct (0.018191)
# 13. previous (0.018040)
# 14. contact_telephone (0.016130)
# 15. month_sep (0.015999)
# 16. poutcome_failure (0.014573)
# 17. job_blue-collar (0.006204)
# 18. default_no (0.006167)
# 19. default_unknown (0.006005)
# 20. age (0.005366)
# 21. month_apr (0.005261)
# 22. job_student (0.005202)
# 23. month_jul (0.003814)
# 24. job_retired (0.003782)
# 25. month_jun (0.003359)
# 26. month_nov (0.002928)
# 27. month_dec (0.002574)
# 28. month_aug (0.001934)
# 29. day_of_week_mon (0.001202)
# 30. education_basic.9y (0.000858)
# 31. marital_single (0.000840)
# 32. education_university.degree (0.000796)
# 33. marital_married (0.000573)
# 34. campaign (0.000486)
# 35. day_of_week_tue (0.000460)
# 36. day_of_week_wed (0.000389)
# 37. job_services (0.000300)
# 38. education_high.school (0.000286)
# 39. job_admin. (0.000276)
# 40. day_of_week_thu (0.000213)
# 41. day_of_week_fri (0.000205)
# 42. housing_yes (0.000197)
# 43. education_professional.course (0.000196)
# 44. education_unknown (0.000174)
# 45. education_basic.4y (0.000167)
# 46. loan_no (0.000164)
# 47. marital_divorced (0.000157)
# 48. job_technician (0.000155)
# 49. housing_no (0.000153)
# 50. job_self-employed (0.000151)
# 51. education_basic.6y (0.000146)
# 52. job_management (0.000132)
# 53. job_unknown (0.000131)
# 54. loan_yes (0.000118)
# 55. loan_unknown (0.000109)
# 56. job_entrepreneur (0.000106)
# 57. housing_unknown (0.000102)
# 58. marital_unknown (0.000095)
# 59. job_unemployed (0.000056)
# 60. job_housemaid (0.000051)
# 61. education_illiterate (0.000008)
# 62. default_yes (0.000000)
# (0, 0.45860471100166034)

# %%
#Confusion matrix


def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Purples):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        t = "(%.2f)"%(cm[i, j])
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

#Compute confusion matrix
y_pred = clf.predict(x_test)
cnf_matrix = confusion_matrix(y_test, y_prediction)
np.set_printoptions(precision=2)

#Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=range(len(set(y_test))), normalize = True,
                     title='Confusion matrix')
# Out:
# Normalized confusion matrix
